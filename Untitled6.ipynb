# %%
from csv import DictReader

# Open the CSV file and read it into a list of dictionaries and ignore unicode errors
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as ms

#Importación de Archivos desde el drive


with open('/content/winemag-data-130k-v2.csv', encoding='utf-8', errors='ignore') as f:
    reader = DictReader(f)
    wines = list(reader)


# The wines variable is now a list of dictionaries, one for each row in the CSV file. This is the sample output of a single entry:
# {'': '1',
#  'name': 'Laurenz V Charming Gruner Veltliner 2014',
#  'grape': '',
#  'region': 'Kamptal, Austria',
#  'variety': 'White Wine',
#  'rating': '90.0',

# %%
# This example creates a new list that only has wines from Napa Valley. The new list is called napa_wines:
napa_wines = []
for wine in wines:
    # Check if the 'region' key exists before accessing it
    if 'region' in wine and 'Napa' in wine['region']:
        napa_wines.append(wine)
        napa_wines

# %%
import pandas as pd

df = pd.read_csv('/content/winemag-data-130k-v2.csv')
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
import pandas as pd
df = pd.read_csv("/content/winemag-data-130k-v2.csv", index_col=0) # read the csv file and set the index column to 0
df.head() # show the first 5 rows of the dataframe
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
#extracción de datos
dict_data = df.to_dict()
# You'll get several keys, one for each column in the dataframe. You can access the values of a column by using the column name as a key. You'll also
# get the index of each row as a key. You can access the values of a row by using the index as a key.

dict_data['designation']
# Out:
# {0: 'Vulkà Bianco',
#  1: 'Avidagos',
#  2: nan,
#  3: 'Reserve Late Harvest',
#  4: "Vintner's Reserve Wild Child Block",
#  5: 'Ars In Vitro',
#  6: 'Belsito',
#  7: nan,
#  8: 'Shine',
#  9: 'Les Natures',
#  10: 'Mountain Cuvée',
#  11: nan,
#  12: nan,
#  13: 'Rosso',
#  14: nan,
#  15: 'Devon',
#  16: 'Felix',
#  17: 'Winemaker Selection',
#  18: 'Vendimia Seleccionada Finca Valdelayegua Single Vineyard Crianza',
#  19: nan,
#  20: 'Vin de Maison',
#  21: nan,
#  22: 'Ficiligno',
#  23: 'Signature Selection',
#  24: 'Aynat',
#  25: 'King Ridge Vineyard',
#  26: 'Dalila',
#  27: nan,
#  28: 'Mascaria Barricato',
#  29: nan,
#  30: 'Nouveau',
#  31: "Calanìca Nero d'Avola-Merlot",
#  32: 'Calanìca Grillo-Viognier',
#  33: 'Puma Springs Vineyard',
#  34: nan,
#  35: 'Hyland',
#  36: 'Estate',
#  37: 'Missoni',
#  38: 'I Tratturi',
#  39: 'Purato Made With Organic Grapes',
#  40: nan,
#  41: nan,
#  42: 'Nouveau',
#  43: nan,
#  44: nan,
#  45: '#SocialSecret',
#  46: 'Sallier de la Tour',
#  47: nan,
#  48: nan,
#  49: 'Eté Indien',
#  50: 'Scialo',
#  51: 'Gran Reserva',
#  52: 'Dolia',
#  53: "La Fleur d'Amélie",
#  54: 'Rosso',
#  55: 'Estate Bottled',
#  56: nan,
#  57: 'Sallier de la Tour',
#  58: 'Reserve',
#  59: nan,
#  60: 'Estate',
#  61: 'Prugneto',
#  62: 'Alder Ridge Vineyard',
#  63: 'Brut Rosé',
#  64: 'Golden Horn',
#  65: nan,
#  66: nan,
#  67: 'Inspired',
#  68: nan,
#  69: 'Brut Rosé',
#  70: nan,
#  71: 'Old Vine',
#  72: 'Daginestra',
#  73: 'Bella Vetta Vineyard',
#  74: 'Estate Grown',
#  75: 'The Cypher',
#  76: nan,
#  77: 'Made With Organic Grapes',
#  78: 'Rosé of',
#  79: 'Bridão',
#  80: 'Special Release Reserva',
#  81: nan,
#  82: 'La Réserve',
#  83: 'Jester Sangiovese',
#  84: 'Classic',
#  85: 'Undone Dry',
#  86: nan,
#  87: 'Blau Vineyards',
#  88: 'Le Mandorle Riserva',
#  89: nan,
#  90: 'Siena',
#  91: nan,
#  92: 'Magnificat',
#  93: nan,
#  94: 'Grand Klasse Reserve Lawrence Vineyards',
#  95: nan,
#  96: nan,
#  97: 'Ingle Vineyard',
#  98: 'Dono Riserva',
#  99: 'Intreccio Library Selection',
#  100: nan,
#  101: 'Red Oak Vineyard',
#  102: 'Yellow Dog Vineyard',
#  103: 'Single Vineyard Falaris Hill',
#  104: 'Nativo',
#  105: 'Villa Antinori',
#  106: 'Castiglioni',
#  107: 'Ammiraglia Massovivo',
#  108: 'J.D. Hurley',
#  109: 'Le Volte',
#  110: 'Les Quartelets',
#  111: 'Wolff Vineyard',
#  112: 'Semifonte',
#  113: 'Poetico',
#  114: 'BDX',
#  115: nan,
#  116: 'Camp 4 Vineyard',
#  117: 'Estate',
#  118: 'Toscano',
#  119: 'Schoenenbourg Grand Cru Vendanges Tardives',
#  120: 'Bricco Rocche Prapó',
#  121: 'Stuhlmuller Vineyard',
#  122: 'Rockpile Cemetary Vineyard',
#  123: "Parson's Flat",
#  124: nan,
#  125: 'Cabernet Sauvignon Reserve',
#  126: 'Vendages Tardives',
#  127: 'Alsace One',
#  128: nan,
#  129: "Philosophers' Stone",
#  130: 'Bricco Rocche Brunate',
#  131: 'Gentil',
#  132: 'Grand Reserve',
#  133: nan,
#  134: nan,
#  135: 'Sorano',
#  136: nan,
#  137: 'Hope Marguerite',
#  138: 'Crustacés',
#  139: 'Cuvée Jerémy Sélection de Grains Nobles',
#  140: 'Costa Bruna',
#  141: 'Vigna dei Pola',
#  142: nan,
#  143: 'Hunawihr Clos Windsbuhl',
#  144: 'K Block',
#  145: 'Guidotti Vineyard',
#  146: 'Family Reserve',
#  147: 'Family Reserve',
#  148: 'Dry',
#  149: 'Destruction Level',
#  150: "Ruth's Reach",
#  151: 'Gerações Colheita Seleccionada Branco',
#  152: 'Estate Reserve',
#  153: 'Old 900',
#  154: 'Single Vineyard Estate Bottled',
#  155: nan,
#  156: 'Graacher Himmelreich Spätlese',
#  157: 'Grande Reserva Tinto',
#  158: 'Bellezza Gran Selezione',
#  159: 'Filo di Seta',
#  160: nan,
#  161: 'Mr. Nibbles',
#  162: 'Claiborne Vineyard',
#  163: 'Hospices Civils de Romanèche Thurins',
#  164: 'Condesa Real Premium Blend',
#  165: '20 Barrels',
#  166: 'Charles de Batz',
#  167: nan,
#  168: 'Rector Creek Vineyard',
#  169: 'Dutton Ranch',
#  170: 'Brauneberger Feinherb',
#  171: nan,
#  172: 'The 7th Generation Gran Reserva Estate Bottled',
#  173: nan,
#  174: nan,
#  175: 'De Silva',
#  176: 'Unusual Cabernet-Shiraz-Zinfandel',
#  177: nan,
#  178: 'Jack London Vineyard',
#  179: 'Les Vénérables Vieilles Vignes',
#  180: 'Lucia Highland Vineyard',
#  181: 'Mission Ranch',
#  182: 'M. Vigna',
#  183: nan,
#  184: nan,
#  185: 'Envero Gran Reserva',
#  186: 'Wiley Vineyard',
#  187: 'Montenero',
#  188: 'Casa La Joya Reserve',
#  189: 'Natura',
#  190: 'Campole',
#  191: 'The Trial of John Montford',
#  192: 'Le Pietre Santambrogio',
#  193: nan,
#  194: nan,
#  195: 'Riserva',
#  196: 'Pancole',
#  197: '21 Gables',
#  198: 'Four Soil Mélange',
#  199: 'Rising Starr Estate Bottled',
#  200: 'Riserva',
#  201: 'Nova Domus Riserva',
#  202: nan,
#  203: 'Montes Claros Garrafeira',
#  204: 'Gesture',
#  205: 'October Night',
#  206: nan,
#  207: 'Home Ranch Teldeschi Vineyards Century Old Vine',
#  208: 'Reserve',
#  209: nan,
#  210: nan,
#  211: 'Les Christins',
#  212: 'Fermentado en Barrica',
#  213: '1105',
#  214: 'Verah',
#  215: 'French Blend',
#  216: nan,
#  217: nan,
#  218: nan,
#  219: 'Megyer Dry',
#  220: nan,
#  221: 'Passion Riserva',
#  222: 'Trentennale',
#  223: nan,
#  224: 'Lunta',
#  225: nan,
#  226: nan,
#  227: 'Grace House',
#  228: 'Semi-Dry',
#  229: 'Costa Del Sol',
#  230: nan,
#  231: nan,
#  232: 'Red Belly Black',
#  233: 'Reserve',
#  234: 'Cerasuolo Rosè',
#  235: 'Thompson Vineyard',
#  236: 'Kiss Ridge Vineyard',
#  237: nan,
#  238: 'The Derelict Vineyard',
#  239: nan,
#  240: nan,
#  241: nan,
#  242: 'Reserve Selection',
#  243: 'Blanc de Blanc',
#  244: 'Herederos de François Lurton Villafrance de Duero',
#  245: 'Reserve',
#  246: 'Destinations',
#  247: 'Reserve',
#  248: 'Estate Single Vineyard',
#  249: 'Petit Verdot-Merlot',
#  250: 'Estate',
#  251: 'Papillon Estate',
#  252: 'Seity',
#  253: 'Reserve',
#  254: nan,
#  255: 'Reserva',
#  256: 'Goat-Roti',
#  257: 'The William',
#  258: nan,
#  259: 'Noir 46',
#  260: 'Estate',
#  261: 'Estate Blend Gran Reserva',
#  262: 'Fairytale',
#  263: 'Monument',
#  264: nan,
#  265: 'Nine Yards',
#  266: 'Corte Malbec-Bonarda-Petit Verdot',
#  267: 'Torre di Giano Vigna il Pino',
#  268: 'Terso',
#  269: nan,
#  270: nan,
#  271: nan,
#  272: 'Sirmian',
#  273: 'B Crux',
#  274: 'Estrosa',
#  275: 'Reserva de Familia',
#  276: 'Old Vines',
#  277: nan,
#  278: 'Bishop Creek',
#  279: nan,
#  280: 'Schiefer Reserve',
#  281: 'Bench Break Vineyard',
#  282: 'Dulcamara',
#  283: 'Bella Vida Vineyard Unfiltered',
#  284: 'Marchiori Vineyard Block C2',
#  285: 'Steiner Kögl Erste Lage',
#  286: 'Rincon Vineyard',
#  287: 'Braó Vinyes Velles',
#  288: 'Kremser Gebling Erste Lage',
#  289: 'Fortune Teller',
#  290: nan,
#  291: nan,
#  292: 'Vin Jaune',
#  293: "Green's Vineyard",
#  294: 'Synthesis',
#  295: 'Treana Red',
#  296: 'Grey [Glacier] Single Block Trinidad Vineyard',
#  297: nan,
#  298: nan,
#  299: 'Pinay',
#  300: 'Estate',
#  301: 'Whiteline No Oak',
#  302: nan,
#  303: '4 Vigne',
#  304: 'Vignassa',
#  305: nan,
#  306: nan,
#  307: 'Les Dames Huguettes',
#  308: 'Asirtiko Athiri',
#  309: nan,
#  310: nan,
#  311: nan,
#  312: nan,
#  313: nan,
#  314: nan,
#  315: 'Extra Dry',
#  316: 'Les Amants Mont-Pérat',
#  317: nan,
#  318: 'Reserva',
#  319: 'Millesimato Brut',
#  320: 'Col di Manza Extra Dry Millesimato',
#  321: 'Brut',
#  322: 'Millesimato Dry',
#  323: 'Gran Araucano',
#  324: 'Matiú Brut',
#  325: nan,
#  326: 'Extra Dry',
#  327: 'Legado Reserva',
#  328: 'Alluvium Blanc',
#  329: 'Reserve',
#  330: "Lila's Cuvée",
#  331: 'Visión',
#  332: 'Palazzo Rosso Brut',
#  333: 'Col del Sas Extra Dry',
#  334: 'Mosaïque Rosé Brut',
#  335: 'Arió Extra Dry',
#  336: 'Costa',
#  337: nan,
#  338: nan,
#  339: '1887 Rosado',
#  340: 'Tradition',
#  341: 'Serracino Reserve',
#  342: nan,
#  343: 'Grand Reserve',
#  344: 'Gran Reserva',
#  345: 'Rare',
#  346: 'Rare',
#  347: 'Kiedrich Gräfenberg Trockenbeerenauslese',
#  348: 'Grand',
#  349: 'RunRig',
#  350: 'Vignolo Riserva',
#  351: 'Eszencia',
#  352: 'South River',
#  353: 'Le Montrachet',
#  354: 'Kiedrich Gräfenberg Beerenauslese',
#  355: 'Sweetwater',
#  356: "Georgia's Paddock",
#  357: 'Vieilles Vignes',
#  358: 'Hattenheimer Hassel Auslese',
#  359: 'Les Chenevottes Premier Cru',
#  360: 'Descendant',
#  361: 'Simposio',
#  362: 'Jamie',
#  363: nan,
#  364: 'Weber Vineyard',
#  365: 'St. Andrews Single Vineyard Release',
#  366: 'Vorberg',
#  367: 'Reserva de la Familia',
#  368: nan,
#  369: nan,
#  370: 'Cherryblock Vineyard',
#  371: 'Castel Ringberg',
#  372: 'Classico',
#  373: 'I Fiori del Borgo',
#  374: "Kathleen's Vineyard",
#  375: 'Vino in Musica',
#  376: 'Zuc de Volpe',
#  377: 'Vigneto Massoni',
#  378: 'Private Reserve',
#  379: 'Bianco dei Sorni',
#  380: 'Estate Bottled',
#  381: 'Vigne Alte',
#  382: 'Estate Grown Reserve',
#  383: 'Vigneto Santa Cecilia',
#  384: 'Sanct Valentin',
#  385: nan,
#  386: 'Windacre Vineyard',
#  387: 'Reserve Fume',
#  388: 'Paragon Vineyard',
#  389: 'Terlano Classico',
#  390: 'Reserve',
#  391: 'Reserve',
#  392: nan,
#  393: 'Castillo de Molina Reserva',
#  394: 'Reserva',
#  395: 'Rylint',
#  396: 'Ancient Vines',
#  397: 'Visión',
#  398: 'Estate Selection',
#  399: 'Extra Dry',
#  400: 'Brut',
#  401: 'Millesimato Extra Dry',
#  402: 'Casa la Joya Reserve',
#  403: 'Le Bon Viveur',
#  404: 'White Hawk Vineyard',
#  405: 'Extra Dry',
#  406: 'Brut Mosaïque',
#  407: 'Casa',
#  408: 'Millesimato Extra Dry',
#  409: 'Dry',
#  410: nan,
#  411: 'Split Oak Vineyard',
#  412: 'Canah Brut',
#  413: nan,
#  414: 'Stefany Extra Dry',
#  415: nan,
#  416: 'Extra Dry',
#  417: nan,
#  418: 'Biokult Zweigelt Pinot Noir',
#  419: nan,
#  420: nan,
#  421: 'Confidential Source',
#  422: 'Blue Mountain Vineyard',
#  423: 'Kittl',
#  424: 'Verdigris',
#  425: 'Bridge Lane',
#  426: 'Seis',
#  427: 'Cuvée Gabriella Brut Rosé',
#  428: 'Crazy Creatures',
#  429: 'The Estates Clifton Hill Vineyard',
#  430: 'McGinley Vineyard',
#  431: 'Indie',
#  432: 'Upland Vineyard',
#  433: 'Stepping Stones',
#  434: "Rocche dell'Annunziata",
#  435: 'Lage Modler',
#  436: 'Gold Label',
#  437: "Henry's Blend",
#  438: 'Século',
#  439: 'Marqués de Montejos Selección',
#  440: nan,
#  441: 'Rosé',
#  442: 'Caya',
#  443: 'Estate Grown',
#  444: 'Altweingarten',
#  445: 'Vigorosa Rosato',
#  446: nan,
#  447: 'Domaine de la Vieille Cure Sur Lie',
#  448: 'Domaine de la Becassonne',
#  449: 'Pas Dosé Aligi Sassu',
#  450: 'Classe M',
#  451: 'Messaggero',
#  452: 'Les Tillets',
#  453: 'Brut Prestige',
#  454: 'Reserve Icewine',
#  455: 'Reserve',
#  456: 'Brut',
#  457: 'Solomon Hills Vineyard',
#  458: 'Gran Cuvée Pas Operé',
#  459: 'Tzarina No 1 Brut',
#  460: 'Ridgecrest Vineyards',
#  461: 'Stoller Vineyards',
#  462: 'Blagny Premier Cru',
#  463: 'Cuvée Marguerite Brut',
#  464: 'Westhofen Morstein GG Trocken',
#  465: 'Morar',
#  466: 'Blanc de Blancs Brut',
#  467: 'Evenstad Reserve',
#  468: 'Ürziger Würzgarten Alte Reben GG Trocken',
#  469: 'Wehlener Sonnenuhr Kabinett',
#  470: 'Édition Limitée Extra Brut',
#  471: 'Les Chatelots Premier Cru',
#  472: 'Les Feusselottes Premier Cru',
#  473: 'Gerações Colheita Seleccionada',
#  474: 'Les Grands Nots Millesimé Brut',
#  475: 'Clone 6',
#  476: 'La Castellana',
#  477: nan,
#  478: 'Grand Cru Family Reserve Brut',
#  479: 'Riserva',
#  480: 'Stella Mae',
#  481: 'Costera',
#  482: "Ocean's Ghost",
#  483: nan,
#  484: 'Petit',
#  485: nan,
#  486: 'L de Lyeth',
#  487: 'Tovè',
#  488: nan,
#  489: nan,
#  490: 'Reserva Brut',
#  491: 'Kellermeister Privat Goldberg',
#  492: nan,
#  493: nan,
#  494: nan,
#  495: 'Battonage',
#  496: 'Collection Blanco',
#  497: 'Babcock Vineyard',
#  498: 'Annabella',
#  499: "L'Esprit de Provence",
#  500: 'Rosado',
#  501: 'Silvaspoons Vineyard',
#  502: 'Muscato',
#  503: nan,
#  504: 'Réserve Grand Veneur',
#  505: nan,
#  506: nan,
#  507: 'Clifton Vineyard',
#  508: nan,
#  509: 'Quantum',
#  510: 'Coastview Vineyard',
#  511: 'Cuvée St Clément',
#  512: 'B. Zéro Brut Dosage',
#  513: 'El Adobo Ranch Vineyard',
#  514: '20 Barrels Limited Edition Peralillo Estate',
#  515: 'Silver Eagle Vineyard',
#  516: 'Soul Patch Estate Grown',
#  517: 'Starr Ridge Vineyard',
#  518: "Le Clos l'Evêque Premier Cru",
#  519: 'The Brat',
#  520: 'Doux Sawyer Lindquist Vineyard',
#  521: 'Sawyer Lindquist Vineyard',
#  522: 'Sims Vineyard',
#  523: "Steve's Reserve",
#  524: 'Wallula',
#  525: 'Rincon Vineyard',
#  526: 'Prince Hill Vineyard Reserve',
#  527: 'Trocken',
#  528: 'Brut Zéro Sélection',
#  529: 'Bucher Vineyard',
#  530: 'Cuvée Alexandre Apalta Vineyard Made With Organic Grapes',
#  531: 'Blanc de Noir',
#  532: 'Diversité',
#  533: 'Équinoxe',
#  534: 'Di Domenico',
#  535: 'Trocken',
#  536: nan,
#  537: nan,
#  538: 'Bradley Vineyard',
#  539: 'Twin Creeks Estate',
#  540: 'Bien Nacido Vineyard',
#  541: 'Solomon Hills Vineyard',
#  542: 'Praepositus Passito',
#  543: 'Cañon Creek Vineyard',
#  544: 'Reckoning',
#  545: 'Les Sommets',
#  546: "Gap's Crown Vineyard",
#  547: 'Stolpman Vineyard',
#  548: 'Thomas Road',
#  549: 'Resa 56',
#  550: 'Estate Reserve',
#  551: 'Pagani Ranch',
#  552: nan,
#  553: "Winemaker's Selection Reserva",
#  554: 'Mas Negrel Cadenet',
#  555: nan,
#  556: 'Gran Resalte',
#  557: 'Bien Nacido Vineyard',
#  558: 'Enigma',
#  559: 'Hail Mary',
#  560: 'Headpruned Block',
#  561: 'Durell Vineyard',
#  562: nan,
#  563: 'Rancho Santa Rosa Vineyard',
#  564: 'Fire Light',
#  565: 'Shapeshifter',
#  566: 'If Six Was Nine Reserve',
#  567: 'Benegas Lynch La Encerrada Estate Vineyard',
#  568: 'Reserve',
#  569: 'La Reyna Blanca Vineyard',
#  570: 'Art Den Hoed Vineyard',
#  571: nan,
#  572: nan,
#  573: nan,
#  574: 'Tradition',
#  575: nan,
#  576: 'Les Terrasses de Pressac',
#  577: 'Pinot Noir',
#  578: 'Château Jean de Bel Air',
#  579: nan,
#  580: nan,
#  581: 'Orange Oak Ridge Vineyard',
#  582: nan,
#  583: 'Unfiltered Estate',
#  584: nan,
#  585: 'StevensSteel',
#  586: 'Classic',
#  587: 'Classic',
#  588: nan,
#  589: nan,
#  590: nan,
#  591: 'GV',
#  592: 'Summit View Vineyard',
#  593: nan,
#  594: 'La Decelle',
#  595: nan,
#  596: nan,
#  597: 'Furth-Palt',
#  598: 'Starlight',
#  599: nan,
#  600: 'Le Marne',
#  601: 'Viña Kristel',
#  602: nan,
#  603: nan,
#  604: 'Reserva 1423',
#  605: "Gran Reserve Winemaker's Selection",
#  606: 'Bomba',
#  607: 'Steel-Ox',
#  608: 'Verdelho and Sauvignon Blanc',
#  609: 'Estate',
#  610: "Charlotte's Home Estate",
#  611: 'Toyon Farm',
#  612: 'Caverio',
#  613: 'Paço de São Lourenço',
#  614: nan,
#  615: nan,
#  616: 'Dutton Ranch',
#  617: 'Millesimato Extra Dry',
#  618: 'Unfiltered',
#  619: 'Brut',
#  620: 'Dry',
#  621: nan,
#  622: 'Sidewinder',
#  623: 'Black Mamba',
#  624: "Koos-Koos-Kia Colter's Creek Vineyard",
#  625: nan,
#  626: 'Memorio Creari',
#  627: 'Sivoy',
#  628: 'Alluvial Fans',
#  629: 'Pinpoint Extreme',
#  630: 'Aliette',
#  631: 'Vendanges Tardives',
#  632: 'Wineck-Schlossberg Grand Cru',
#  633: nan,
#  634: "Tina's Block Maple Vineyard",
#  635: 'Capellanía',
#  636: 'The Factor',
#  637: 'Altenberg de Bergheim Grand Cru',
#  638: 'Kitterlé Grand Cru',
#  639: 'Kessler Grand Cru',
#  640: 'Tinaquaic Vineyard',
#  641: nan,
#  642: 'Monte de Carrapatelo Colheita Seleccionada Tinto',
#  643: nan,
#  644: 'Estate Grown',
#  645: 'Freedom Hill Vineyard',
#  646: 'Lagoalva Barrel Selection Tinto',
#  647: nan,
#  648: 'Brauneberger Juffer-Sonnenuhr Spätlese Grosse Lage',
#  649: 'Three Twins Vineyard Fallen Feather',
#  650: nan,
#  651: 'Pfersigberg Grand Cru',
#  652: nan,
#  653: nan,
#  654: 'Rosacker Grand Cru',
#  655: "Lodi Native Marian's Vineyard",
#  656: "Nancy's",
#  657: 'Night Sky',
#  658: nan,
#  659: nan,
#  660: 'Le Roi Soleil',
#  661: nan,
#  662: 'Ornato',
#  663: 'Rockpile Vineyard',
#  664: "Siri d'Jermu",
#  665: 'Costa Bruna',
#  666: nan,
#  667: 'Soplo',
#  668: 'Virgin Berry',
#  669: 'McClellan Estate Vineyard',
#  670: 'Eco Made with Organic Grapes',
#  671: nan,
#  672: 'Dry',
#  673: 'Charles Vineyard',
#  674: 'Estate',
#  675: nan,
#  676: 'Dijon Clone',
#  677: 'Smeriglio Riserva',
#  678: 'Smeriglio',
#  679: 'Sagemoor',
#  680: 'Selección Crianza',
#  681: 'ALX',
#  682: 'Metodo Classico',
#  683: 'Cignale',
#  684: 'Canoe Ridge Vineyard',
#  685: 'Emmaline Ann Vineyard',
#  686: 'Acclivi',
#  687: 'Gravel Ridge Vineyard',
#  688: 'Reserve 34',
#  689: 'Quattro Santa Barbara Highlands Vineyard',
#  690: "Nit'ana",
#  691: 'Ghielmetti Vineyard Micro-lot Reserve',
#  692: 'Capatosta',
#  693: nan,
#  694: 'Reserve',
#  695: 'Riserva Ducale Oro Gran Selezione',
#  696: 'Pioneer Block 20 Dillons Point Cash Block',
#  697: 'von Gösing',
#  698: 'Little Bear Creek',
#  699: 'Estate Wine',
#  700: nan,
#  701: 'Les Clans',
#  702: nan,
#  703: nan,
#  704: nan,
#  705: nan,
#  706: 'TwoB',
#  707: "L'Esprit de Provence",
#  708: 'VieVité Extraordinaire',
#  709: 'DCV2 Estate Four Clones Vineyard',
#  710: nan,
#  711: 'Cohen Vineyard Dutton Ranch',
#  712: 'Keefer Ranch',
#  713: 'Dichotomy',
#  714: 'Bannockburn',
#  715: 'Trisagio Malbec-Petit Verdot-Tannat',
#  716: 'Unravelled',
#  717: 'No. 5',
#  718: 'Bote Chardonnay-Fernão Pires-Vital',
#  719: 'Grande Réserve du Président',
#  720: nan,
#  721: nan,
#  722: nan,
#  723: 'Santola',
#  724: 'Mont Sec Vineyards',
#  725: 'Meriame',
#  726: 'Casa de Paços',
#  727: nan,
#  728: 'Reserva',
#  729: 'Audaz Branco',
#  730: nan,
#  731: 'Bin 068',
#  732: 'Mont-Avril',
#  733: nan,
#  734: nan,
#  735: 'Don David Reserve',
#  736: nan,
#  737: 'Casa Ermelinda Freitas Monte de Baía',
#  738: 'Henry Legarde',
#  739: 'Riserva',
#  740: nan,
#  741: nan,
#  742: nan,
#  743: 'Treborce Vineyard',
#  744: 'Campo Quadro Riserva',
#  745: 'Pato Frio',
#  746: 'Classic',
#  747: nan,
#  748: 'Fiori Delle Stelle Ice Wine',
#  749: 'Baron de Hoen',
#  750: 'Thornton Vineyard',
#  751: '347 Vineyards',
#  752: nan,
#  753: 'Effort',
#  754: nan,
#  755: nan,
#  756: nan,
#  757: "Julia's Vineyard",
#  758: nan,
#  759: 'Reserve, Vista del Monte Vineyard',
#  760: 'Estate Grown',
#  761: 'Antu',
#  762: 'Solo',
#  763: 'Ipsum',
#  764: 'Cuvée Christine',
#  765: 'The Griffin',
#  766: nan,
#  767: nan,
#  768: nan,
#  769: 'Synthesi',
#  770: 'Mumm de Cramant Blanc de Blancs',
#  771: 'Ocean Reserve',
#  772: 'Grande Réserve Blanc de Blancs Grand Cru Brut',
#  773: 'Grande Reserva',
#  774: 'Lorna Marie',
#  775: 'West Block',
#  776: 'Oenophile Premier Cru Blanc de Blancs Extra Brut',
#  777: 'Cràtis',
#  778: 'Winderlea Vineyard',
#  779: 'Assemblage Brut',
#  780: nan,
#  781: 'Giulio Ferrari Riserva del Fondatore',
#  782: 'Cuvée M',
#  783: 'Big River Ranch',
#  784: "VT '08",
#  785: nan,
#  786: 'Aneto Tinto',
#  787: 'Rutherford Estate Vineyard',
#  788: 'Bramare Marchiori Vineyard',
#  789: 'Apollo Dry',
#  790: 'Signature',
#  791: 'Chehalem Mountain Vineyard',
#  792: 'La Sérénité des Grands Chênes',
#  793: 'Tuttorosso',
#  794: nan,
#  795: 'Divin de Corbin',
#  796: nan,
#  797: nan,
#  798: nan,
#  799: nan,
#  800: nan,
#  801: 'Tawny Estate',
#  802: 'Le Griottier',
#  803: 'Upright Klipsun Vineyard',
#  804: 'Lola Evergreen Vineyard',
#  805: nan,
#  806: 'Small Lot',
#  807: 'Farrago',
#  808: 'Le Vele',
#  809: 'Parcela 23',
#  810: nan,
#  811: 'Castell',
#  812: 'Perli Vineyards',
#  813: 'Cuvee Juveniles',
#  814: nan,
#  815: 'Soleil',
#  816: 'Pre-Emption Vineyard',
#  817: 'Block Selection Reserve Block N. 10',
#  818: 'Belle Grâce',
#  819: nan,
#  820: 'Made With Organic Grapes',
#  821: 'Brut',
#  822: nan,
#  823: nan,
#  824: nan,
#  825: nan,
#  826: 'Ciampoleto',
#  827: nan,
#  828: 'K-libre',
#  829: nan,
#  830: nan,
#  831: 'Roche Grès',
#  832: 'Coeur de Vendanges',
#  833: nan,
#  834: 'Reserva Estate Bottled',
#  835: 'Flower Label',
#  836: 'Cinta Púrpura Brut Reserva',
#  837: 'Sweet Reserva',
#  838: 'Les Collines Vineyard',
#  839: 'Yellow Dog Vineyard',
#  840: nan,
#  841: nan,
#  842: nan,
#  843: "Proprietor's Reserve",
#  844: 'Bianco',
#  845: 'Aquilae Bio',
#  846: 'Rosenberg',
#  847: 'Galets Oligocène',
#  848: 'Clos de Jeu',
#  849: nan,
#  850: 'Grèves Premier Cru',
#  851: 'Champ Salomon',
#  852: 'Grand A du Petit Léon',
#  853: 'Thanisch Kabinett',
#  854: nan,
#  855: 'Reserve',
#  856: 'Taburno',
#  857: nan,
#  858: nan,
#  859: nan,
#  860: 'Erato De Portola Trail Vineyard',
#  861: 'Rosso',
#  862: nan,
#  863: 'Rio Vista Vineyard',
#  864: 'Trocken',
#  865: 'Laluci',
#  866: 'Handpicked Grenache',
#  867: 'Estate',
#  868: 'Gran Reserva',
#  869: 'Larner',
#  870: 'Estate Bottled',
#  871: nan,
#  872: nan,
#  873: 'Dry',
#  874: nan,
#  875: nan,
#  876: 'Idus',
#  877: 'Alfeo',
#  878: nan,
#  879: nan,
#  880: 'Sonoma Estate',
#  881: 'Coraje',
#  882: nan,
#  883: 'Campo al Fico',
#  884: 'Brut Rose',
#  885: nan,
#  886: 'La Mère Grand',
#  887: 'Reserva Branco',
#  888: 'Slide Mountain Vineyard',
#  889: 'Red Label',
#  890: 'Estate',
#  891: nan,
#  892: 'Stone Tree Vineyard Intuition Reserve',
#  893: 'Heavy Metal',
#  894: 'Castello di Montepò',
#  895: 'Giuseppe Olivi Memento',
#  896: 'Signature Selection',
#  897: 'Dividend',
#  898: nan,
#  899: 'Fonterutoli',
#  900: 'Criança',
#  901: 'Reserva Branco',
#  902: 'Reserve Bingham Vineyard',
#  903: nan,
#  904: 'Pajè',
#  905: 'Super Nero',
#  906: 'Reddy Vineyard',
#  907: 'Bruto',
#  908: nan,
#  909: nan,
#  910: 'Grand Vin',
#  911: 'Samsó Seulle',
#  912: 'Three Otters Pinot Noir',
#  913: 'Asureti Valley',
#  914: 'Grand Reserve',
#  915: 'Atração',
#  916: 'Renovação Estate Vineyards',
#  917: 'Bussia',
#  918: 'Ginestra',
#  919: 'Reserve',
#  920: 'Breathing Space',
#  921: 'Conde Vimioso Colheita Seleccionada Branco',
#  922: 'Altosur',
#  923: nan,
#  924: nan,
#  925: 'Vin Doux Naturel',
#  926: 'Roll Fermentor',
#  927: 'Casal Garcia Rosé',
#  928: nan,
#  929: 'Estate',
#  930: 'Alberti 154',
#  931: nan,
#  932: 'Tradition',
#  933: nan,
#  934: 'Vieilles Vignes',
#  935: 'Vieilles Vignes',
#  936: "Ian's Reserve",
#  937: 'Stoller Vineyards',
#  938: 'II Crianza',
#  939: "Melange d'Amis Reserve",
#  940: 'Grande Réserve Premier Cru Brut',
#  941: 'Goru Verde',
#  942: nan,
#  943: 'Crianza',
#  944: 'Estate',
#  945: "Director's",
#  946: 'Reserve Winston Hill Vineyard',
#  947: 'Evel Tinto',
#  948: 'Santos da Casa Tinto',
#  949: nan,
#  950: nan,
#  951: 'Rennie Vineyard Organic Grapes',
#  952: 'XIC',
#  953: 'i',
#  954: 'Reserve Bottling',
#  955: 'Nirvasco',
#  956: 'Anni Venti Metodo Classico',
#  957: 'Ritchie Vineyard',
#  958: 'Wine Wings Garnacha',
#  959: 'Brut Mosaïque',
#  960: nan,
#  961: nan,
#  962: 'Demoiselle Tête de Cuvée Brut',
#  963: nan,
#  964: 'Argillaia',
#  965: 'Vecchie Vigne',
#  966: nan,
#  967: 'Selected Terroir',
#  968: 'Chiaretto',
#  969: 'Pionero',
#  970: nan,
#  971: 'Pop Rosé Extra Dry',
#  972: nan,
#  973: 'Alexander School Reserve Big Barrel',
#  974: 'Rough House Red',
#  975: 'P',
#  976: "Summation Vintner's Reserve",
#  977: 'Estate Grown',
#  978: 'White X',
#  979: 'Sauvignon',
#  980: 'Capitel della Crosara',
#  981: 'Premius Bordeaux Sauvignon',
#  982: 'Col di Luna',
#  983: nan,
#  984: 'Rosso di Valachia',
#  985: 'Reserve Las Barrancas Vineyards',
#  986: 'Late Bottled Vintage',
#  987: nan,
#  988: nan,
#  989: nan,
#  990: nan,
#  991: 'Les Mirlandes',
#  992: 'Grande Tradition',
#  993: nan,
#  994: 'Les Belles Vignes',
#  995: 'Edèlmio',
#  996: 'Terre di Giumara',
#  997: 'Patchwork',
#  998: nan,
#  999: nan,
#  ...}

# %%
print(dict_data['designation'][0], # get the value of the 'name' column for the row with index 0
dict_data['designation'][3], # get the value of the 'rating' column for the row with index 0
dict_data['designation'][18], # get the value of the 'region' column for the row with index 0
)
# Out:
# Vulkà Bianco Reserve Late Harvest Vendimia Seleccionada Finca Valdelayegua Single Vineyard Crianza
